# %%
# Week 1 - Foundation
# FinSight AI - Intelligent Financial Risk & Insights Platform
# Topics: Python basics, pandas, numpy, data visualization

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("FinSight AI - Week 1 Started ✅")
print(f"pandas: {pd.__version__}")
print(f"numpy: {np.__version__}")
# Out:
# FinSight AI - Week 1 Started ✅
# pandas: 3.0.3
# numpy: 2.4.4

# %% [markdown]
# DAY 2 - Loading and Exploring the Lending Club Dataset

# %%
dataset = pd.read_csv('../data/loan.csv')
print("Dataset loaded successfully!")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23340\2027704023.py:1: DtypeWarning: Columns (0: desc, 1: next_pymnt_d, 2: verification_status_joint, 3: sec_app_earliest_cr_line, 4: hardship_type, 5: hardship_reason, 6: hardship_status, 7: hardship_start_date, 8: hardship_end_date, 9: payment_plan_start_date, 10: hardship_loan_status, 11: debt_settlement_flag_date, 12: settlement_status, 13: settlement_date) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('../data/loan.csv')
# Dataset loaded successfully!

# %%
dataset.shape
# Out:
# (2260668, 145)

# %%
dataset.head(10)
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
# 5 NaN        NaN       5550         5550           5550.0   36 months
# 6 NaN        NaN       2000         2000           2000.0   36 months
# 7 NaN        NaN       6000         6000           6000.0   36 months
# 8 NaN        NaN       5000         5000           5000.0   36 months
# 9 NaN        NaN       6000         6000           6000.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.56        84.92     C        C1  ...                            NaN
# 1     18.94       777.23     D        D2  ...                            NaN
# 2     17.97       180.69     D        D1  ...                            NaN
# 3     18.94       146.51     D        D2  ...                            NaN
# 4     16.14       731.78     C        C4  ...                            NaN
# 5     15.02       192.45     C        C3  ...                            NaN
# 6     17.97        72.28     D        D1  ...                            NaN
# 7     13.56       203.79     C        C1  ...                            NaN
# 8     17.97       180.69     D        D1  ...                            NaN
# 9     14.47       206.44     C        C2  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
# 1                          NaN                Cash                     N
# 2                          NaN                Cash                     N
# 3                          NaN                Cash                     N
# 4                          NaN                Cash                     N
# 5                          NaN                Cash                     N
# 6                          NaN                Cash                     N
# 7                          NaN           DirectPay                     N
# 8                          NaN                Cash                     N
# 9                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
# 5                       NaN               NaN             NaN
# 6                       NaN               NaN             NaN
# 7                       NaN               NaN             NaN
# 8                       NaN               NaN             NaN
# 9                       NaN               NaN             NaN
#
#   settlement_amount  settlement_percentage settlement_term
# 0               NaN                    NaN             NaN
# 1               NaN                    NaN             NaN
# 2               NaN                    NaN             NaN
# 3               NaN                    NaN             NaN
# 4               NaN                    NaN             NaN
# 5               NaN                    NaN             NaN
# 6               NaN                    NaN             NaN
# 7               NaN                    NaN             NaN
# 8               NaN                    NaN             NaN
# 9               NaN                    NaN             NaN
#
# [10 rows x 145 columns]

# %%
dataset.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='str', length=145)

# %%
dataset.isna()
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# 0        True       True      False        False            False  False
# 1        True       True      False        False            False  False
# 2        True       True      False        False            False  False
# 3        True       True      False        False            False  False
# 4        True       True      False        False            False  False
# ...       ...        ...        ...          ...              ...    ...
# 2260663  True       True      False        False            False  False
# 2260664  True       True      False        False            False  False
# 2260665  True       True      False        False            False  False
# 2260666  True       True      False        False            False  False
# 2260667  True       True      False        False            False  False
#
#          int_rate  installment  grade  sub_grade  ...  \
# 0           False        False  False      False  ...
# 1           False        False  False      False  ...
# 2           False        False  False      False  ...
# 3           False        False  False      False  ...
# 4           False        False  False      False  ...
# ...           ...          ...    ...        ...  ...
# 2260663     False        False  False      False  ...
# 2260664     False        False  False      False  ...
# 2260665     False        False  False      False  ...
# 2260666     False        False  False      False  ...
# 2260667     False        False  False      False  ...
#
#          hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                                  True                          True
# 1                                  True                          True
# 2                                  True                          True
# 3                                  True                          True
# 4                                  True                          True
# ...                                 ...                           ...
# 2260663                            True                          True
# 2260664                            True                          True
# 2260665                            True                          True
# 2260666                            True                          True
# 2260667                            True                          True
#
#          disbursement_method  debt_settlement_flag  debt_settlement_flag_date  \
# 0                      False                 False                       True
# 1                      False                 False                       True
# 2                      False                 False                       True
# 3                      False                 False                       True
# 4                      False                 False                       True
# ...                      ...                   ...                        ...
# 2260663                False                 False                       True
# 2260664                False                 False                       True
# 2260665                False                 False                       True
# 2260666                False                 False                       True
# 2260667                False                 False                       True
#
#          settlement_status  settlement_date  settlement_amount  \
# 0                     True             True               True
# 1                     True             True               True
# 2                     True             True               True
# 3                     True             True               True
# 4                     True             True               True
# ...                    ...              ...                ...
# 2260663               True             True               True
# 2260664               True             True               True
# 2260665               True             True               True
# 2260666               True             True               True
# 2260667               True             True               True
#
#          settlement_percentage  settlement_term
# 0                         True             True
# 1                         True             True
# 2                         True             True
# 3                         True             True
# 4                         True             True
# ...                        ...              ...
# 2260663                   True             True
# 2260664                   True             True
# 2260665                   True             True
# 2260666                   True             True
# 2260667                   True             True
#
# [2260668 rows x 145 columns]

# %%
dataset.isna().sum()
# Out:
# id                       2260668
# member_id                2260668
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
#                           ...
# settlement_status        2227612
# settlement_date          2227612
# settlement_amount        2227612
# settlement_percentage    2227612
# settlement_term          2227612
# Length: 145, dtype: int64

# %% [markdown]
# We can see that first and last column are entirely empty. They kind of look important.

# %%
dataset.isna().sum().sum()
# Out:
# np.int64(108666958)

# %% [markdown]
# What percentage of loans are defaulted?

# %%
dataset['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid                                             1041952
# Current                                                 919695
# Charged Off                                             261655
# Late (31-120 days)                                       21897
# In Grace Period                                           8952
# Late (16-30 days)                                         3737
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     31
# Name: count, dtype: int64

# %%
dataset.groupby('grade').size().plot(kind='bar')
plt.title('Loan Count by Grade')
# Out:
# Text(0.5, 1.0, 'Loan Count by Grade')

# %%
dataset['loan_status'].unique()
# Out:
# <StringArray>
# [                                            'Current',
#                                           'Fully Paid',
#                                   'Late (31-120 days)',
#                                      'In Grace Period',
#                                          'Charged Off',
#                                    'Late (16-30 days)',
#                                              'Default',
#   'Does not meet the credit policy. Status:Fully Paid',
#  'Does not meet the credit policy. Status:Charged Off']
# Length: 9, dtype: str

# %% [markdown]
# These loan statuses should be considered defaulted:
#
# Charged Off
# Default
# Late (31-120 days)
# Does not meet the credit policy. Status:Charged Off

# %%
dataset[(dataset['loan_status'] == 'Charged Off') | (dataset['loan_status'] == 'Default') | (dataset['loan_status'] == 'Late (16-30 days)') | (dataset['loan_status'] == 'Does not meet the credit policy. Status:Charged Off')]
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 5040    NaN        NaN       8000         8000           8000.0   36 months
# 9620    NaN        NaN      16000        16000          16000.0   36 months
# 18860   NaN        NaN      10000        10000          10000.0   36 months
# 22225   NaN        NaN      12000        12000          12000.0   36 months
# 22452   NaN        NaN      30000        30000          30000.0   36 months
# ...      ..        ...        ...          ...              ...         ...
# 2260633 NaN        NaN      30000        30000          29725.0   60 months
# 2260638 NaN        NaN      30000        30000          30000.0   36 months
# 2260640 NaN        NaN      20700        20700          20700.0   60 months
# 2260654 NaN        NaN      30000        30000          30000.0   60 months
# 2260655 NaN        NaN      18000        18000          18000.0   60 months
#
#          int_rate  installment grade sub_grade  ...  \
# 5040         6.46       245.05     A        A1  ...
# 9620        15.02       554.81     C        C3  ...
# 18860       15.02       346.76     C        C3  ...
# 22225       16.91       427.30     C        C5  ...
# 22452       18.94      1098.78     D        D2  ...
# ...           ...          ...   ...       ...  ...
# 2260633     30.17       973.74     F        F3  ...
# 2260638     21.45      1137.20     D        D5  ...
# 2260640     12.62       466.98     C        C1  ...
# 2260654     17.09       747.03     D        D1  ...
# 2260655     30.65       589.57     F        F4  ...
#
#         hardship_payoff_balance_amount hardship_last_payment_amount  \
# 5040                               NaN                          NaN
# 9620                               NaN                          NaN
# 18860                              NaN                          NaN
# 22225                              NaN                          NaN
# 22452                              NaN                          NaN
# ...                                ...                          ...
# 2260633                            NaN                          NaN
# 2260638                            NaN                          NaN
# 2260640                            NaN                          NaN
# 2260654                            NaN                          NaN
# 2260655                            NaN                          NaN
#
#         disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 5040              DirectPay                     N                       NaN
# 9620                   Cash                     N                       NaN
# 18860                  Cash                     N                       NaN
# 22225                  Cash                     N                       NaN
# 22452                  Cash                     N                       NaN
# ...                     ...                   ...                       ...
# 2260633                Cash                     N                       NaN
# 2260638                Cash                     N                       NaN
# 2260640                Cash                     N                       NaN
# 2260654                Cash                     N                       NaN
# 2260655                Cash                     N                       NaN
#
#         settlement_status settlement_date settlement_amount  \
# 5040                  NaN             NaN               NaN
# 9620                  NaN             NaN               NaN
# 18860                 NaN             NaN               NaN
# 22225                 NaN             NaN               NaN
# 22452                 NaN             NaN               NaN
# ...                   ...             ...               ...
# 2260633               NaN             NaN               NaN
# 2260638               NaN             NaN               NaN
# 2260640               NaN             NaN               NaN
# 2260654               NaN             NaN               NaN
# 2260655               NaN             NaN               NaN
#
#          settlement_percentage settlement_term
# 5040                       NaN             NaN
# 9620                       NaN             NaN
# 18860                      NaN             NaN
# 22225                      NaN             NaN
# 22452                      NaN             NaN
# ...                        ...             ...
# 2260633                    NaN             NaN
# 2260638                    NaN             NaN
# 2260640                    NaN             NaN
# 2260654                    NaN             NaN
# 2260655                    NaN             NaN
#
# [266184 rows x 145 columns]

# %%
dataset['is_default'] = dataset['loan_status'].isin(['Charged Off','Late (16-30 days)','Default','Does not meet the credit policy. Status:Charged Off'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23340\784665895.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataset['is_default'] = dataset['loan_status'].isin(['Charged Off','Late (16-30 days)','Default','Does not meet the credit policy. Status:Charged Off'])

# %%
dataset['is_default'] = dataset['is_default'].astype(int)

# %%
dataset['is_default'].unique()
# Out:
# array([0, 1])

# %%
dataset['is_default'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: is_default, dtype: int64

# %%
dataset['is_default'].mean() * 100
# Out:
# np.float64(11.774572825377277)

# %%
dataset.groupby('grade')['is_default'].mean() * 100
# Out:
# grade
# A     3.242985
# B     7.835348
# C    13.036783
# D    18.640729
# E    26.438561
# F    34.622010
# G    37.762985
# Name: is_default, dtype: float64

# %% [markdown]
# Loan grade is a strong predictor of default — Grade G borrowers default at 11x the rate of Grade A borrowers, validating the grading system as a core risk signal.

# %%
dataset.drop(['NAN %', 'Empty%'], axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dataset.drop(['NAN %', 'Empty%'], axis=1, inplace= True)
#
# File s:\Python\AI_ML_Project\.venv\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File s:\Python\AI_ML_Project\.venv\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
#    4643             if labels is not None:
# -> 4644                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4645
#    4646         if inplace:
#    4647             self._update_inplace(obj)
#
# File s:\Python\AI_ML_Project\.venv\Lib\site-packages\pandas\core\generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4682                 if not isinstance(axis, MultiIndex):
#    4683                     raise AssertionError("axis must be a MultiIndex")
#    4684                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4685             else:
# -> 4686                 new_axis = axis.drop(labels, errors=errors)
#    4687             indexer = axis.get_indexer(new_axis)
#    4688
#    4689         # Case for non-unique axis
#
# File s:\Python\AI_ML_Project\.venv\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['NAN %', 'Empty%'] not found in axis"

# %% [markdown]
# Large chunk of this dataset is empty

# %%
(dataset.isna().sum() / dataset.shape[0] * 100).sort_values(ascending=False).head(30)
# Out:
# id                                            100.000000
# member_id                                     100.000000
# url                                           100.000000
# orig_projected_additional_accrued_interest     99.627278
# deferral_term                                  99.530537
# hardship_start_date                            99.530537
# hardship_loan_status                           99.530537
# hardship_payoff_balance_amount                 99.530537
# hardship_end_date                              99.530537
# hardship_type                                  99.530537
# hardship_last_payment_amount                   99.530537
# hardship_amount                                99.530537
# hardship_status                                99.530537
# hardship_reason                                99.530537
# hardship_dpd                                   99.530537
# hardship_length                                99.530537
# payment_plan_start_date                        99.530537
# settlement_term                                98.537777
# debt_settlement_flag_date                      98.537777
# settlement_status                              98.537777
# settlement_date                                98.537777
# settlement_amount                              98.537777
# settlement_percentage                          98.537777
# sec_app_mths_since_last_major_derog            98.410116
# sec_app_revol_util                             95.302981
# revol_bal_joint                                95.221766
# sec_app_earliest_cr_line                       95.221722
# sec_app_num_rev_accts                          95.221722
# sec_app_open_acc                               95.221722
# sec_app_mort_acc                               95.221722
# dtype: float64

# %% [markdown]
# DATA CLEANING TODAY

# %%
columns_to_keep = list()
series = (dataset.isna().sum() / dataset.shape[0] * 100).sort_values(ascending=False)
for index, values in series.items():
    if values < 30:
        columns_to_keep.append(index)

print(columns_to_keep)
# Out:
# ['mths_since_recent_inq', 'emp_title', 'num_tl_120dpd_2m', 'emp_length', 'mo_sin_old_il_acct', 'bc_util', 'percent_bc_gt_75', 'bc_open_to_buy', 'mths_since_recent_bc', 'pct_tl_nvr_dlq', 'avg_cur_bal', 'mo_sin_old_rev_tl_op', 'num_rev_accts', 'mo_sin_rcnt_rev_tl_op', 'num_tl_30dpd', 'tot_cur_bal', 'mo_sin_rcnt_tl', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_op_rev_tl', 'num_rev_tl_bal_gt_0', 'num_il_tl', 'total_rev_hi_lim', 'tot_coll_amt', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'num_bc_tl', 'num_actv_rev_tl', 'tot_hi_cred_lim', 'total_il_high_credit_limit', 'num_sats', 'num_bc_sats', 'total_bal_ex_mort', 'total_bc_limit', 'acc_open_past_24mths', 'mort_acc', 'title', 'last_pymnt_d', 'revol_util', 'dti', 'pub_rec_bankruptcies', 'collections_12_mths_ex_med', 'chargeoff_within_12_mths', 'tax_liens', 'last_credit_pull_d', 'inq_last_6mths', 'earliest_cr_line', 'open_acc', 'delinq_amnt', 'total_acc', 'acc_now_delinq', 'delinq_2yrs', 'pub_rec', 'annual_inc', 'zip_code', 'loan_amnt', 'pymnt_plan', 'loan_status', 'issue_d', 'verification_status', 'home_ownership', 'installment', 'grade', 'sub_grade', 'term', 'funded_amnt_inv', 'funded_amnt', 'int_rate', 'collection_recovery_fee', 'recoveries', 'total_rec_late_fee', 'last_pymnt_amnt', 'policy_code', 'application_type', 'purpose', 'addr_state', 'revol_bal', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_rec_int', 'total_rec_prncp', 'total_pymnt_inv', 'total_pymnt', 'hardship_flag', 'disbursement_method', 'debt_settlement_flag', 'is_default']

# %%
CleanData = dataset[columns_to_keep]
CleanData
# Out:
#          mths_since_recent_inq       emp_title  num_tl_120dpd_2m emp_length  \
# 0                          2.0            Chef               0.0  10+ years
# 1                          4.0     Postmaster                0.0  10+ years
# 2                         14.0  Administrative               0.0    6 years
# 3                          5.0   IT Supervisor               0.0  10+ years
# 4                         13.0        Mechanic               0.0  10+ years
# ...                        ...             ...               ...        ...
# 2260663                    9.0    house keeper               0.0  10+ years
# 2260664                    0.0   Skilled Labor               0.0   < 1 year
# 2260665                    3.0         Teacher               0.0  10+ years
# 2260666                    5.0             NaN               0.0        NaN
# 2260667                    0.0      BABYSITTER               0.0    3 years
#
#          mo_sin_old_il_acct  bc_util  percent_bc_gt_75  bc_open_to_buy  \
# 0                     140.0      5.9               0.0         34360.0
# 1                     163.0      8.3               0.0         13761.0
# 2                      87.0      0.0               0.0         13800.0
# 3                      62.0     75.2             100.0          1239.0
# 4                      53.0      8.9               0.0          8471.0
# ...                     ...      ...               ...             ...
# 2260663               157.0     70.9              66.7          1807.0
# 2260664               163.0     19.6              50.0          9162.0
# 2260665               134.0     93.2             100.0           136.0
# 2260666               170.0     14.6               0.0         18789.0
# 2260667                 NaN     49.7              20.0          9816.0
#
#          mths_since_recent_bc  pct_tl_nvr_dlq  ...  out_prncp  out_prncp_inv  \
# 0                         1.0           100.0  ...    2386.02        2386.02
# 1                         4.0            95.0  ...   29387.75       29387.75
# 2                        77.0           100.0  ...    4787.21        4787.21
# 3                        64.0           100.0  ...    3831.93        3831.93
# 4                         2.0            92.3  ...   29339.02       29339.02
# ...                       ...             ...  ...        ...            ...
# 2260663                   9.0           100.0  ...    8687.20        8687.20
# 2260664                 141.0            76.9  ...       0.00           0.00
# 2260665                 111.0           100.0  ...    5993.27        5993.27
# 2260666                  16.0            88.2  ...    9924.69        9924.69
# 2260667                  10.0           100.0  ...   13541.01       13541.01
#
#          total_rec_int  total_rec_prncp  total_pymnt_inv   total_pymnt  \
# 0                53.04           113.98           167.02    167.020000
# 1               894.86           612.25          1507.11   1507.110000
# 2               141.10           212.79           353.89    353.890000
# 3               118.64           168.07           286.71    286.710000
# 4               762.23           660.98          1423.21   1423.210000
# ...                ...              ...              ...           ...
# 2260663        2048.16          3312.80          5360.96   5360.960000
# 2260664        2499.80         12000.00         14499.80  14499.802172
# 2260665        1300.21          4006.73          5306.94   5306.940000
# 2260666        3131.98          2075.31          5207.29   5207.290000
# 2260667        4346.51          3008.99          7355.50   7355.500000
#
#          hardship_flag  disbursement_method  debt_settlement_flag  is_default
# 0                    N                 Cash                     N           0
# 1                    N                 Cash                     N           0
# 2                    N                 Cash                     N           0
# 3                    N                 Cash                     N           0
# 4                    N                 Cash                     N           0
# ...                ...                  ...                   ...         ...
# 2260663              N                 Cash                     N           0
# 2260664              N                 Cash                     N           0
# 2260665              N                 Cash                     N           0
# 2260666              N                 Cash                     N           0
# 2260667              N                 Cash                     N           0
#
# [2260668 rows x 88 columns]

# %%
CleanData.shape
# Out:
# (2260668, 88)

# %%
CleanData.columns
# Out:
# Index(['mths_since_recent_inq', 'emp_title', 'num_tl_120dpd_2m', 'emp_length',
#        'mo_sin_old_il_acct', 'bc_util', 'percent_bc_gt_75', 'bc_open_to_buy',
#        'mths_since_recent_bc', 'pct_tl_nvr_dlq', 'avg_cur_bal',
#        'mo_sin_old_rev_tl_op', 'num_rev_accts', 'mo_sin_rcnt_rev_tl_op',
#        'num_tl_30dpd', 'tot_cur_bal', 'mo_sin_rcnt_tl',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_op_rev_tl',
#        'num_rev_tl_bal_gt_0', 'num_il_tl', 'total_rev_hi_lim', 'tot_coll_amt',
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'num_bc_tl',
#        'num_actv_rev_tl', 'tot_hi_cred_lim', 'total_il_high_credit_limit',
#        'num_sats', 'num_bc_sats', 'total_bal_ex_mort', 'total_bc_limit',
#        'acc_open_past_24mths', 'mort_acc', 'title', 'last_pymnt_d',
#        'revol_util', 'dti', 'pub_rec_bankruptcies',
#        'collections_12_mths_ex_med', 'chargeoff_within_12_mths', 'tax_liens',
#        'last_credit_pull_d', 'inq_last_6mths', 'earliest_cr_line', 'open_acc',
#        'delinq_amnt', 'total_acc', 'acc_now_delinq', 'delinq_2yrs', 'pub_rec',
#        'annual_inc', 'zip_code', 'loan_amnt', 'pymnt_plan', 'loan_status',
#        'issue_d', 'verification_status', 'home_ownership', 'installment',
#        'grade', 'sub_grade', 'term', 'funded_amnt_inv', 'funded_amnt',
#        'int_rate', 'collection_recovery_fee', 'recoveries',
#        'total_rec_late_fee', 'last_pymnt_amnt', 'policy_code',
#        'application_type', 'purpose', 'addr_state', 'revol_bal',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_rec_int',
#        'total_rec_prncp', 'total_pymnt_inv', 'total_pymnt', 'hardship_flag',
#        'disbursement_method', 'debt_settlement_flag', 'is_default'],
#       dtype='str')

# %%
CleanData.drop(['title', 'zip_code'], axis=1, inplace=True)

# %%
CleanData.shape
# Out:
# (2260668, 86)

# %%
CleanData.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Data columns (total 86 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   mths_since_recent_inq       float64
#  1   emp_title                   str
#  2   num_tl_120dpd_2m            float64
#  3   emp_length                  str
#  4   mo_sin_old_il_acct          float64
#  5   bc_util                     float64
#  6   percent_bc_gt_75            float64
#  7   bc_open_to_buy              float64
#  8   mths_since_recent_bc        float64
#  9   pct_tl_nvr_dlq              float64
#  10  avg_cur_bal                 float64
#  11  mo_sin_old_rev_tl_op        float64
#  12  num_rev_accts               float64
#  13  mo_sin_rcnt_rev_tl_op       float64
#  14  num_tl_30dpd                float64
#  15  tot_cur_bal                 float64
#  16  mo_sin_rcnt_tl              float64
#  17  num_accts_ever_120_pd       float64
#  18  num_actv_bc_tl              float64
#  19  num_op_rev_tl               float64
#  20  num_rev_tl_bal_gt_0         float64
#  21  num_il_tl                   float64
#  22  total_rev_hi_lim            float64
#  23  tot_coll_amt                float64
#  24  num_tl_90g_dpd_24m          float64
#  25  num_tl_op_past_12m          float64
#  26  num_bc_tl                   float64
#  27  num_actv_rev_tl             float64
#  28  tot_hi_cred_lim             float64
#  29  total_il_high_credit_limit  float64
#  30  num_sats                    float64
#  31  num_bc_sats                 float64
#  32  total_bal_ex_mort           float64
#  33  total_bc_limit              float64
#  34  acc_open_past_24mths        float64
#  35  mort_acc                    float64
#  36  last_pymnt_d                str
#  37  revol_util                  float64
#  38  dti                         float64
#  39  pub_rec_bankruptcies        float64
#  40  collections_12_mths_ex_med  float64
#  41  chargeoff_within_12_mths    float64
#  42  tax_liens                   float64
#  43  last_credit_pull_d          str
#  44  inq_last_6mths              float64
#  45  earliest_cr_line            str
#  46  open_acc                    float64
#  47  delinq_amnt                 float64
#  48  total_acc                   float64
#  49  acc_now_delinq              float64
#  50  delinq_2yrs                 float64
#  51  pub_rec                     float64
#  52  annual_inc                  float64
#  53  loan_amnt                   int64
#  54  pymnt_plan                  str
#  55  loan_status                 str
#  56  issue_d                     str
#  57  verification_status         str
#  58  home_ownership              str
#  59  installment                 float64
#  60  grade                       str
#  61  sub_grade                   str
#  62  term                        str
#  63  funded_amnt_inv             float64
#  64  funded_amnt                 int64
#  65  int_rate                    float64
#  66  collection_recovery_fee     float64
#  67  recoveries                  float64
#  68  total_rec_late_fee          float64
#  69  last_pymnt_amnt             float64
#  70  policy_code                 int64
#  71  application_type            str
#  72  purpose                     str
#  73  addr_state                  str
#  74  revol_bal                   int64
#  75  initial_list_status         str
#  76  out_prncp                   float64
#  77  out_prncp_inv               float64
#  78  total_rec_int               float64
#  79  total_rec_prncp             float64
#  80  total_pymnt_inv             float64
#  81  total_pymnt                 float64
#  82  hardship_flag               str
#  83  disbursement_method         str
#  84  debt_settlement_flag        str
#  85  is_default                  int64
# dtypes: float64(61), int64(5), str(20)
# memory usage: 1.4 GB

# %%
CleanData['issue_d'].unique()
# Out:
# <StringArray>
# ['Dec-2018', 'Nov-2018', 'Oct-2018', 'Sep-2018', 'Aug-2018', 'Jul-2018',
#  'Jun-2018', 'May-2018', 'Apr-2018', 'Mar-2018',
#  ...
#  'Dec-2007', 'Nov-2007', 'Oct-2007', 'Sep-2007', 'Aug-2007', 'Jul-2007',
#  'Jun-2007', 'Dec-2017', 'Nov-2017', 'Oct-2017']
# Length: 139, dtype: str

# %%
CleanData['term']=CleanData['term'].str.replace(' months','')
CleanData['term']=CleanData['term'].astype(int)
CleanData['term'].dtype
# Out:
# dtype('int64')

# %%
CleanData['last_pymnt_d']= pd.to_datetime(CleanData['last_pymnt_d'])
CleanData['last_pymnt_d']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23340\2999038794.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   CleanData['last_pymnt_d']= pd.to_datetime(CleanData['last_pymnt_d'])
# 0         2019-02-01
# 1         2019-02-01
# 2         2019-02-01
# 3         2019-02-01
# 4         2019-02-01
#              ...
# 2260663   2019-02-01
# 2260664   2018-08-01
# 2260665   2019-02-01
# 2260666   2019-02-01
# 2260667   2019-02-01
# Name: last_pymnt_d, Length: 2260668, dtype: datetime64[us]

# %%
CleanData['last_credit_pull_d']= pd.to_datetime(CleanData['last_credit_pull_d'])
CleanData['last_credit_pull_d']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23340\3712060589.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   CleanData['last_credit_pull_d']= pd.to_datetime(CleanData['last_credit_pull_d'])
# 0         2019-02-01
# 1         2019-02-01
# 2         2019-02-01
# 3         2019-02-01
# 4         2019-02-01
#              ...
# 2260663   2019-02-01
# 2260664   2017-09-01
# 2260665   2019-02-01
# 2260666   2019-02-01
# 2260667   2019-02-01
# Name: last_credit_pull_d, Length: 2260668, dtype: datetime64[us]

# %%
CleanData['earliest_cr_line'] = pd.to_datetime(CleanData['earliest_cr_line'])
CleanData['issue_d'] = pd.to_datetime(CleanData['issue_d'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23340\1649638134.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   CleanData['earliest_cr_line'] = pd.to_datetime(CleanData['earliest_cr_line'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23340\1649638134.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   CleanData['issue_d'] = pd.to_datetime(CleanData['issue_d'])

# %%
CleanData.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Data columns (total 86 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   mths_since_recent_inq       float64
#  1   emp_title                   str
#  2   num_tl_120dpd_2m            float64
#  3   emp_length                  str
#  4   mo_sin_old_il_acct          float64
#  5   bc_util                     float64
#  6   percent_bc_gt_75            float64
#  7   bc_open_to_buy              float64
#  8   mths_since_recent_bc        float64
#  9   pct_tl_nvr_dlq              float64
#  10  avg_cur_bal                 float64
#  11  mo_sin_old_rev_tl_op        float64
#  12  num_rev_accts               float64
#  13  mo_sin_rcnt_rev_tl_op       float64
#  14  num_tl_30dpd                float64
#  15  tot_cur_bal                 float64
#  16  mo_sin_rcnt_tl              float64
#  17  num_accts_ever_120_pd       float64
#  18  num_actv_bc_tl              float64
#  19  num_op_rev_tl               float64
#  20  num_rev_tl_bal_gt_0         float64
#  21  num_il_tl                   float64
#  22  total_rev_hi_lim            float64
#  23  tot_coll_amt                float64
#  24  num_tl_90g_dpd_24m          float64
#  25  num_tl_op_past_12m          float64
#  26  num_bc_tl                   float64
#  27  num_actv_rev_tl             float64
#  28  tot_hi_cred_lim             float64
#  29  total_il_high_credit_limit  float64
#  30  num_sats                    float64
#  31  num_bc_sats                 float64
#  32  total_bal_ex_mort           float64
#  33  total_bc_limit              float64
#  34  acc_open_past_24mths        float64
#  35  mort_acc                    float64
#  36  last_pymnt_d                datetime64[us]
#  37  revol_util                  float64
#  38  dti                         float64
#  39  pub_rec_bankruptcies        float64
#  40  collections_12_mths_ex_med  float64
#  41  chargeoff_within_12_mths    float64
#  42  tax_liens                   float64
#  43  last_credit_pull_d          datetime64[us]
#  44  inq_last_6mths              float64
#  45  earliest_cr_line            datetime64[us]
#  46  open_acc                    float64
#  47  delinq_amnt                 float64
#  48  total_acc                   float64
#  49  acc_now_delinq              float64
#  50  delinq_2yrs                 float64
#  51  pub_rec                     float64
#  52  annual_inc                  float64
#  53  loan_amnt                   int64
#  54  pymnt_plan                  str
#  55  loan_status                 str
#  56  issue_d                     datetime64[us]
#  57  verification_status         str
#  58  home_ownership              str
#  59  installment                 float64
#  60  grade                       str
#  61  sub_grade                   str
#  62  term                        int64
#  63  funded_amnt_inv             float64
#  64  funded_amnt                 int64
#  65  int_rate                    float64
#  66  collection_recovery_fee     float64
#  67  recoveries                  float64
#  68  total_rec_late_fee          float64
#  69  last_pymnt_amnt             float64
#  70  policy_code                 int64
#  71  application_type            str
#  72  purpose                     str
#  73  addr_state                  str
#  74  revol_bal                   int64
#  75  initial_list_status         str
#  76  out_prncp                   float64
#  77  out_prncp_inv               float64
#  78  total_rec_int               float64
#  79  total_rec_prncp             float64
#  80  total_pymnt_inv             float64
#  81  total_pymnt                 float64
#  82  hardship_flag               str
#  83  disbursement_method         str
#  84  debt_settlement_flag        str
#  85  is_default                  int64
# dtypes: datetime64[us](4), float64(61), int64(6), str(15)
# memory usage: 1.4 GB

# %%
CleanData.select_dtypes(include = str).columns.tolist()
# Out:
# ['emp_title',
#  'emp_length',
#  'pymnt_plan',
#  'loan_status',
#  'verification_status',
#  'home_ownership',
#  'grade',
#  'sub_grade',
#  'application_type',
#  'purpose',
#  'addr_state',
#  'initial_list_status',
#  'hardship_flag',
#  'disbursement_method',
#  'debt_settlement_flag']

# %%
annual_inc_median = CleanData['annual_inc'].median()
dti_median = CleanData['dti'].median()
revol_util_median = CleanData['revol_util'].median()
inq_last_6mths_median = CleanData['inq_last_6mths'].median()

# %%
CleanData['annual_inc']=CleanData['annual_inc'].fillna(annual_inc_median)
CleanData['dti']=CleanData['dti'].fillna(dti_median)
CleanData['revol_util']=CleanData['revol_util'].fillna(revol_util_median)
CleanData['inq_last_6mths']=CleanData['inq_last_6mths'].fillna(inq_last_6mths_median)

# %%
CleanData['annual_inc'].isna().sum()
# Out:
# np.int64(0)

# %%
CleanData.to_csv('../data/clean_loan_data.csv', index=False)

# %% [markdown]
# DAY 4 - Using Numpy to get statistics

# %%
df = pd.read_csv('../data/clean_loan_data.csv')

# %%
df['loan_amnt'].dtype
# Out:
# dtype('int64')

# %%
loan_amnt_mean = np.mean(df['loan_amnt'])
loan_amnt_median = np.median(df['loan_amnt'])
loan_amnt_std = np.std(df['loan_amnt'])
loan_amnt_25p = np.percentile(df['loan_amnt'],25)
loan_amnt_50p = np.percentile(df['loan_amnt'],50)
loan_amnt_75p = np.percentile(df['loan_amnt'],75)

print("Mean: ",loan_amnt_mean)
print("Median: ", loan_amnt_median)
print("Standar Deviation: ", loan_amnt_std)
print("25 Percentile: ", loan_amnt_25p)
print("50 Percentile: ", loan_amnt_50p)
print("75 Percentile: ", loan_amnt_75p)
# Out:
# Mean:  15046.931227849467
# Median:  12900.0
# Standar Deviation:  9190.243455593203
# 25 Percentile:  8000.0
# 50 Percentile:  12900.0
# 75 Percentile:  20000.0

# %% [markdown]
# Mean (15,046) is higher than Median (12,900) — this means the distribution is right-skewed. A few very large loans are pulling the mean up.
# 25th percentile is 8,000 and 75th is 20,000 — so the middle 50% of loans are between $8K and $20K
# Standard deviation of 9,190 is quite large — there's a wide spread in loan amounts
#
# This right-skew insight is important — it means a small number of borrowers are taking very large loans, which could represent higher risk.

# %%
df['is_default'] = df['loan_status'].isin(['Charged Off','Late (16-30 days)','Default','Does not meet the credit policy. Status:Charged Off'])

# %%
df['is_default'] = df['is_default'].astype(int)

# %%
default_avg_loan_amnt = np.mean(df[df['is_default'] ==1]['loan_amnt'])
nodefault_avg_loan_amnt = np.mean(df[df['is_default'] ==0]['loan_amnt'])
print(default_avg_loan_amnt)
print(nodefault_avg_loan_amnt)
# Out:
# 15551.92874102125
# 14979.534217872893

# %% [markdown]
# Defaulters borrow slightly more ($15,551) than non-defaulters ($14,979), about $570 more on average.
# The difference isn't massive but it's consistent with what you'd expect, people who borrow more are slightly more likely to struggle with repayment.
# This will become a feature in our ML model later.

# %%
default_avg_interest_rate = np.mean(df[df['is_default'] ==1]['int_rate'])
nodefault_avg_interest_rate = np.mean(df[df['is_default'] ==0]['int_rate'])
std_interest_rate = np.std(df['int_rate'])
print(default_avg_interest_rate)
print(nodefault_avg_interest_rate)
print(std_interest_rate)
# Out:
# 15.705964445646622
# 12.74417487430333
# 4.832113164136204

# %% [markdown]
# Defaulters pay 15.7% interest vs non-defaulters at 12.7%, that's a 3% difference. This is huge in credit risk terms.
# It tells us two things:
#
# Lenders already sensed these borrowers were riskier and charged them more
# But higher interest rates also make repayment harder — creating a self-fulfilling cycle
#
# int_rate will likely be one of the top features in our ML model. Remember this when we get to Week 3.

# %%
default_avg_dti = np.mean(df[df['is_default'] ==1]['dti'])
nodefault_avg_dti = np.mean(df[df['is_default'] ==0]['dti'])
print(default_avg_dti)
print(nodefault_avg_dti)
# Out:
# 20.14212345595528
# 18.647461478758412

# %%
(df[df['dti']>30].value_counts().shape[0]/ df.shape[0] * 100)
# Out:
# 8.202575521925377

# %% [markdown]
# Defaulters have higher DTI (20.14) vs non-defaulters (18.64), confirms DTI is a risk signal
# Only 8.2% of borrowers have DTI above 30, these are our highest risk borrowers
#
# Three patterns are emerging across our analysis:
#
# Defaulters borrow more
# Defaulters pay higher interest rates
# Defaulters have higher DTI
#
# These 3 variables together are telling a clear story, and they'll be the backbone of our risk model in Week 3.

# %%
default_avg_annual_inc = np.mean(df[df['is_default'] ==1]['annual_inc'])
nodefault_avg_annual_inc = np.mean(df[df['is_default'] ==0]['annual_inc'])

print(default_avg_annual_inc)
print(nodefault_avg_annual_inc)
# Out:
# 70452.26621476121
# 78998.71333904409

# %%
default_median_annual_inc = np.median(df[df['is_default'] ==1]['annual_inc'])
nodefault_median_annual_inc = np.median(df[df['is_default'] ==0]['annual_inc'])

print(default_median_annual_inc)
print(nodefault_median_annual_inc)
# Out:
# 60000.0
# 65025.36

# %%
print(np.percentile(df['annual_inc'],90))
# Out:
# 130000.0

# %% [markdown]
# So 90% of borrowers earn less than $130,000. That means anyone above $130K is in the top 10% of earners in this dataset.

# %% [markdown]
# Every single metric points in the same direction, defaulters borrow more, pay higher rates, have higher debt burden, and earn less. This is your first complete risk profile.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Day 5 — Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['loan_amnt'], bins=60)
plt.title('Loan Amount Distribution')
plt.xlabel('Loan amount')
plt.ylabel('Number of loans')
plt.savefig('../reports/loan_amount_distribution.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(['A','B','C','D','E','F','G'],[3.242985,7.835348,13.036783,18.640729,26.438561,34.622010,37.762985] )
plt.title('Default pct by Grade')
plt.xlabel('Grade')
plt.ylabel('Percentage of Default%')
plt.savefig('../reports/pctng_distribution.png')
plt.show()

# %%
sns.boxplot(x='is_default', y='int_rate', data=df)
plt.savefig('../reports/boxplot_isdefault_intrate')

# %%
sns.heatmap(df.select_dtypes(include='number').corr(), annot=False)
plt.figure(figsize=(20,16))
plt.savefig('../reports/correlation_heatmap.png')

# %%
temp_list1 = list()
temp_list2 = list()
temp_list1 =(df.groupby(df['purpose'])['is_default'].mean()*100).sort_values(ascending=False).index
temp_list2 =(df.groupby(df['purpose'])['is_default'].mean()*100).sort_values(ascending=False).values
plt.barh(temp_list1,temp_list2)
plt.title("Default Rate by Loan Purpose")
plt.show()
plt.savefig('../reports/default_rate_by_purpose.png')

# %%
df.select_dtypes(include='number').corr()
# Out:
#                        mths_since_recent_inq  num_tl_120dpd_2m  \
# mths_since_recent_inq               1.000000          0.000361
# num_tl_120dpd_2m                    0.000361          1.000000
# mo_sin_old_il_acct                 -0.015480          0.005663
# bc_util                             0.084705         -0.007131
# percent_bc_gt_75                    0.079022         -0.007377
# ...                                      ...               ...
# total_rec_int                      -0.032810          0.004519
# total_rec_prncp                    -0.005113          0.004566
# total_pymnt_inv                    -0.015956          0.005184
# total_pymnt                        -0.015943          0.005194
# is_default                         -0.059728          0.003677
#
#                        mo_sin_old_il_acct   bc_util  percent_bc_gt_75  \
# mths_since_recent_inq           -0.015480  0.084705          0.079022
# num_tl_120dpd_2m                 0.005663 -0.007131         -0.007377
# mo_sin_old_il_acct               1.000000  0.061342          0.056766
# bc_util                          0.061342  1.000000          0.846756
# percent_bc_gt_75                 0.056766  0.846756          1.000000
# ...                                   ...       ...               ...
# total_rec_int                    0.080042  0.203734          0.180406
# total_rec_prncp                  0.099209  0.082969          0.060478
# total_pymnt_inv                  0.105625  0.128139          0.102895
# total_pymnt                      0.105612  0.128177          0.102928
# is_default                      -0.017958  0.074630          0.077130
#
#                        bc_open_to_buy  mths_since_recent_bc  pct_tl_nvr_dlq  \
# mths_since_recent_inq       -0.022846              0.095210        0.030861
# num_tl_120dpd_2m             0.000747              0.005020       -0.017178
# mo_sin_old_il_acct           0.030260              0.056237       -0.104446
# bc_util                     -0.541888              0.149961       -0.031443
# percent_bc_gt_75            -0.440061              0.153076       -0.015105
# ...                               ...                   ...             ...
# total_rec_int               -0.058570              0.017309        0.013677
# total_rec_prncp              0.100868              0.026532        0.058671
# total_pymnt_inv              0.066824              0.025216        0.053129
# total_pymnt                  0.066778              0.025205        0.053107
# is_default                  -0.082103             -0.046832       -0.005646
#
#                        avg_cur_bal  mo_sin_old_rev_tl_op  ...  \
# mths_since_recent_inq    -0.016312              0.005532  ...
# num_tl_120dpd_2m          0.005356              0.007306  ...
# mo_sin_old_il_acct        0.119064              0.214802  ...
# bc_util                   0.076732              0.009144  ...
# percent_bc_gt_75          0.067686              0.023865  ...
# ...                            ...                   ...  ...
# total_rec_int             0.091425              0.082672  ...
# total_rec_prncp           0.175585              0.145292  ...
# total_pymnt_inv           0.172195              0.144481  ...
# total_pymnt               0.172168              0.144465  ...
# is_default               -0.057208             -0.035262  ...
#
#                        last_pymnt_amnt  policy_code  revol_bal  out_prncp  \
# mths_since_recent_inq        -0.038008          NaN   0.010875   0.041005
# num_tl_120dpd_2m              0.003069          NaN  -0.003073  -0.009102
# mo_sin_old_il_acct            0.046787          NaN   0.104301   0.040001
# bc_util                       0.004424          NaN   0.178343  -0.067467
# percent_bc_gt_75              0.003451          NaN   0.142329  -0.075665
# ...                                ...          ...        ...        ...
# total_rec_int                 0.105523          NaN   0.175687   0.092776
# total_rec_prncp               0.668926          NaN   0.223675  -0.295185
# total_pymnt_inv               0.583789          NaN   0.236493  -0.230166
# total_pymnt                   0.583748          NaN   0.236770  -0.231009
# is_default                   -0.176833          NaN  -0.019867  -0.207672
#
#                        out_prncp_inv  total_rec_int  total_rec_prncp  \
# mths_since_recent_inq       0.041010      -0.032810        -0.005113
# num_tl_120dpd_2m           -0.009103       0.004519         0.004566
# mo_sin_old_il_acct          0.040009       0.080042         0.099209
# bc_util                    -0.067463       0.203734         0.082969
# percent_bc_gt_75           -0.075658       0.180406         0.060478
# ...                              ...            ...              ...
# total_rec_int               0.092770       1.000000         0.501711
# total_rec_prncp            -0.295177       0.501711         1.000000
# total_pymnt_inv            -0.230160       0.696212         0.966391
# total_pymnt                -0.231004       0.696466         0.967017
# is_default                 -0.207652       0.041130        -0.216119
#
#                        total_pymnt_inv  total_pymnt  is_default
# mths_since_recent_inq        -0.015956    -0.015943   -0.059728
# num_tl_120dpd_2m              0.005184     0.005194    0.003677
# mo_sin_old_il_acct            0.105625     0.105612   -0.017958
# bc_util                       0.128139     0.128177    0.074630
# percent_bc_gt_75              0.102895     0.102928    0.077130
# ...                                ...          ...         ...
# total_rec_int                 0.696212     0.696466    0.041130
# total_rec_prncp               0.966391     0.967017   -0.216119
# total_pymnt_inv               1.000000     0.999394   -0.132716
# total_pymnt                   0.999394     1.000000   -0.132628
# is_default                   -0.132716    -0.132628    1.000000
#
# [67 rows x 67 columns]

# %% [markdown]
# WEEK 2

# %% [markdown]
# Right now our workflow is:
# CSV file → pandas → analysis
# In real companies it's:
# Database → Python → analysis
# Today we bridge that gap.

# %%
import sqlite3

# %%
conn = sqlite3.connect('../data/finsight.db')

# %%
df.to_sql('loans', conn, if_exists='replace', index=False)
# Out:
# 2260668

# %%
pd.read_sql("SELECT COUNT(*) as total_loans FROM loans", conn)
# Out:
#    total_loans
# 0      2260668

# %% [markdown]
# Below table showing count of loans per grade. Why? Because we get an idea that if that number is falling in grade A, it is comparatively safe and opposite for latter grades like E and G

# %%
pd.read_sql("SELECT grade, COUNT(*) as total_loans FROM loans GROUP BY grade", conn)
# Out:
#   grade  total_loans
# 0     A       433027
# 1     B       663557
# 2     C       650053
# 3     D       324424
# 4     E       135639
# 5     F        41800
# 6     G        12168

# %%
total_loans_by_grade = pd.read_sql("SELECT grade, COUNT(*) as total_loans FROM loans GROUP BY grade", conn)

# %% [markdown]
# Below table showing average intrest rate by grade, AS high we go, interest rate gets lower.

# %%
pd.read_sql("SELECT grade, AVG(int_rate) as avg_int_rate FROM loans GROUP BY grade", conn)
# Out:
#   grade  avg_int_rate
# 0     A      7.084558
# 1     B     10.675819
# 2     C     14.143793
# 3     D     18.143304
# 4     E     21.829848
# 5     F     25.454203
# 6     G     28.074255

# %%
avg_int_rate_bygrade = pd.read_sql("SELECT grade, AVG(int_rate) as avg_int_rate FROM loans GROUP BY grade", conn)

# %% [markdown]
# Below is the table showing default rate by purpose, we can see which purpose is more likely to get defaulted.

# %%
pd.read_sql("SELECT purpose, AVG(is_default)*100 as avg_int_rate FROM loans GROUP BY purpose", conn)
# Out:
#                purpose  avg_int_rate
# 0                  car      8.811894
# 1          credit_card      9.559530
# 2   debt_consolidation     12.796928
# 3          educational     20.754717
# 4     home_improvement     10.240800
# 5                house     11.028580
# 6       major_purchase     10.742393
# 7              medical     12.252619
# 8               moving     14.218009
# 9                other     11.668101
# 10    renewable_energy     15.155709
# 11      small_business     18.607477
# 12            vacation     11.027375
# 13             wedding     12.399151

# %% [markdown]
# Oops! I might got the wrong column name. Edit: I forgot to re-execute the code where 'is-default' column was added in the database.

# %%
df.columns
# Out:
# Index(['mths_since_recent_inq', 'emp_title', 'num_tl_120dpd_2m', 'emp_length',
#        'mo_sin_old_il_acct', 'bc_util', 'percent_bc_gt_75', 'bc_open_to_buy',
#        'mths_since_recent_bc', 'pct_tl_nvr_dlq', 'avg_cur_bal',
#        'mo_sin_old_rev_tl_op', 'num_rev_accts', 'mo_sin_rcnt_rev_tl_op',
#        'num_tl_30dpd', 'tot_cur_bal', 'mo_sin_rcnt_tl',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_op_rev_tl',
#        'num_rev_tl_bal_gt_0', 'num_il_tl', 'total_rev_hi_lim', 'tot_coll_amt',
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'num_bc_tl',
#        'num_actv_rev_tl', 'tot_hi_cred_lim', 'total_il_high_credit_limit',
#        'num_sats', 'num_bc_sats', 'total_bal_ex_mort', 'total_bc_limit',
#        'acc_open_past_24mths', 'mort_acc', 'last_pymnt_d', 'revol_util', 'dti',
#        'pub_rec_bankruptcies', 'collections_12_mths_ex_med',
#        'chargeoff_within_12_mths', 'tax_liens', 'last_credit_pull_d',
#        'inq_last_6mths', 'earliest_cr_line', 'open_acc', 'delinq_amnt',
#        'total_acc', 'acc_now_delinq', 'delinq_2yrs', 'pub_rec', 'annual_inc',
#        'loan_amnt', 'pymnt_plan', 'loan_status', 'issue_d',
#        'verification_status', 'home_ownership', 'installment', 'grade',
#        'sub_grade', 'term', 'funded_amnt_inv', 'funded_amnt', 'int_rate',
#        'collection_recovery_fee', 'recoveries', 'total_rec_late_fee',
#        'last_pymnt_amnt', 'policy_code', 'application_type', 'purpose',
#        'addr_state', 'revol_bal', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_rec_int', 'total_rec_prncp', 'total_pymnt_inv',
#        'total_pymnt', 'hardship_flag', 'disbursement_method',
#        'debt_settlement_flag', 'is_default'],
#       dtype='str')

# %%
pd.read_sql("SELECT purpose, AVG(is_default) * 100 as default_pct FROM loans GROUP BY purpose", conn)
# Out:
#                purpose  default_pct
# 0                  car     8.811894
# 1          credit_card     9.559530
# 2   debt_consolidation    12.796928
# 3          educational    20.754717
# 4     home_improvement    10.240800
# 5                house    11.028580
# 6       major_purchase    10.742393
# 7              medical    12.252619
# 8               moving    14.218009
# 9                other    11.668101
# 10    renewable_energy    15.155709
# 11      small_business    18.607477
# 12            vacation    11.027375
# 13             wedding    12.399151

# %%
default_pct_by_purpose=pd.read_sql("SELECT purpose, AVG(is_default) * 100 as default_pct FROM loans GROUP BY purpose", conn)

# %%
df['addr_state']
# Out:
# 0          NY
# 1          LA
# 2          MI
# 3          WA
# 4          MD
#            ..
# 2260663    VT
# 2260664    OR
# 2260665    IL
# 2260666    AK
# 2260667    NY
# Name: addr_state, Length: 2260668, dtype: str

# %% [markdown]
# Total loan by state here. We get an idea where most amount of loan is going.

# %%
pd.read_sql("SELECT addr_state, SUM(loan_amnt) as total_amnt FROM loans GROUP BY addr_state ORDER BY SUM(loan_amnt)DESC LIMIT 10", conn)
# Out:
#   addr_state  total_amnt
# 0         CA  4808480100
# 1         TX  2931133525
# 2         NY  2767160700
# 3         FL  2333034500
# 4         IL  1410451950
# 5         NJ  1316207975
# 6         GA  1136790825
# 7         PA  1131987950
# 8         OH  1077142925
# 9         VA  1013015875

# %%
top_10_states_with_highest_loan_amnt = pd.read_sql("SELECT addr_state, SUM(loan_amnt) as total_amnt FROM loans GROUP BY addr_state ORDER BY SUM(loan_amnt)DESC LIMIT 10", conn)

# %% [markdown]
# Count of high risk loan. We define high risk if interest rate is above 20 and debt-to-income ratio is above 30

# %%
pd.read_sql("SELECT COUNT(*) AS count_high_risk_loan FROM loans WHERE int_rate>20 AND dti>30", conn)
# Out:
#    count_high_risk_loan
# 0                 34009

# %%
df
# Out:
#          mths_since_recent_inq       emp_title  num_tl_120dpd_2m emp_length  \
# 0                          2.0            Chef               0.0  10+ years
# 1                          4.0     Postmaster                0.0  10+ years
# 2                         14.0  Administrative               0.0    6 years
# 3                          5.0   IT Supervisor               0.0  10+ years
# 4                         13.0        Mechanic               0.0  10+ years
# ...                        ...             ...               ...        ...
# 2260663                    9.0    house keeper               0.0  10+ years
# 2260664                    0.0   Skilled Labor               0.0   < 1 year
# 2260665                    3.0         Teacher               0.0  10+ years
# 2260666                    5.0             NaN               0.0        NaN
# 2260667                    0.0      BABYSITTER               0.0    3 years
#
#          mo_sin_old_il_acct  bc_util  percent_bc_gt_75  bc_open_to_buy  \
# 0                     140.0      5.9               0.0         34360.0
# 1                     163.0      8.3               0.0         13761.0
# 2                      87.0      0.0               0.0         13800.0
# 3                      62.0     75.2             100.0          1239.0
# 4                      53.0      8.9               0.0          8471.0
# ...                     ...      ...               ...             ...
# 2260663               157.0     70.9              66.7          1807.0
# 2260664               163.0     19.6              50.0          9162.0
# 2260665               134.0     93.2             100.0           136.0
# 2260666               170.0     14.6               0.0         18789.0
# 2260667                 NaN     49.7              20.0          9816.0
#
#          mths_since_recent_bc  pct_tl_nvr_dlq  ...  out_prncp  out_prncp_inv  \
# 0                         1.0           100.0  ...    2386.02        2386.02
# 1                         4.0            95.0  ...   29387.75       29387.75
# 2                        77.0           100.0  ...    4787.21        4787.21
# 3                        64.0           100.0  ...    3831.93        3831.93
# 4                         2.0            92.3  ...   29339.02       29339.02
# ...                       ...             ...  ...        ...            ...
# 2260663                   9.0           100.0  ...    8687.20        8687.20
# 2260664                 141.0            76.9  ...       0.00           0.00
# 2260665                 111.0           100.0  ...    5993.27        5993.27
# 2260666                  16.0            88.2  ...    9924.69        9924.69
# 2260667                  10.0           100.0  ...   13541.01       13541.01
#
#          total_rec_int  total_rec_prncp  total_pymnt_inv   total_pymnt  \
# 0                53.04           113.98           167.02    167.020000
# 1               894.86           612.25          1507.11   1507.110000
# 2               141.10           212.79           353.89    353.890000
# 3               118.64           168.07           286.71    286.710000
# 4               762.23           660.98          1423.21   1423.210000
# ...                ...              ...              ...           ...
# 2260663        2048.16          3312.80          5360.96   5360.960000
# 2260664        2499.80         12000.00         14499.80  14499.802172
# 2260665        1300.21          4006.73          5306.94   5306.940000
# 2260666        3131.98          2075.31          5207.29   5207.290000
# 2260667        4346.51          3008.99          7355.50   7355.500000
#
#          hardship_flag  disbursement_method  debt_settlement_flag  is_default
# 0                    N                 Cash                     N           0
# 1                    N                 Cash                     N           0
# 2                    N                 Cash                     N           0
# 3                    N                 Cash                     N           0
# 4                    N                 Cash                     N           0
# ...                ...                  ...                   ...         ...
# 2260663              N                 Cash                     N           0
# 2260664              N                 Cash                     N           0
# 2260665              N                 Cash                     N           0
# 2260666              N                 Cash                     N           0
# 2260667              N                 Cash                     N           0
#
# [2260668 rows x 86 columns]

# %% [markdown]
# WEEK 2: DAY 2 - Today we are designing the tables and relational database

# %%
df.columns
# Out:
# Index(['mths_since_recent_inq', 'emp_title', 'num_tl_120dpd_2m', 'emp_length',
#        'mo_sin_old_il_acct', 'bc_util', 'percent_bc_gt_75', 'bc_open_to_buy',
#        'mths_since_recent_bc', 'pct_tl_nvr_dlq', 'avg_cur_bal',
#        'mo_sin_old_rev_tl_op', 'num_rev_accts', 'mo_sin_rcnt_rev_tl_op',
#        'num_tl_30dpd', 'tot_cur_bal', 'mo_sin_rcnt_tl',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_op_rev_tl',
#        'num_rev_tl_bal_gt_0', 'num_il_tl', 'total_rev_hi_lim', 'tot_coll_amt',
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'num_bc_tl',
#        'num_actv_rev_tl', 'tot_hi_cred_lim', 'total_il_high_credit_limit',
#        'num_sats', 'num_bc_sats', 'total_bal_ex_mort', 'total_bc_limit',
#        'acc_open_past_24mths', 'mort_acc', 'last_pymnt_d', 'revol_util', 'dti',
#        'pub_rec_bankruptcies', 'collections_12_mths_ex_med',
#        'chargeoff_within_12_mths', 'tax_liens', 'last_credit_pull_d',
#        'inq_last_6mths', 'earliest_cr_line', 'open_acc', 'delinq_amnt',
#        'total_acc', 'acc_now_delinq', 'delinq_2yrs', 'pub_rec', 'annual_inc',
#        'loan_amnt', 'pymnt_plan', 'loan_status', 'issue_d',
#        'verification_status', 'home_ownership', 'installment', 'grade',
#        'sub_grade', 'term', 'funded_amnt_inv', 'funded_amnt', 'int_rate',
#        'collection_recovery_fee', 'recoveries', 'total_rec_late_fee',
#        'last_pymnt_amnt', 'policy_code', 'application_type', 'purpose',
#        'addr_state', 'revol_bal', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_rec_int', 'total_rec_prncp', 'total_pymnt_inv',
#        'total_pymnt', 'hardship_flag', 'disbursement_method',
#        'debt_settlement_flag', 'is_default'],
#       dtype='str')

# %%
df['pymnt_plan']
# Out:
# 0          n
# 1          n
# 2          n
# 3          n
# 4          n
#           ..
# 2260663    n
# 2260664    n
# 2260665    n
# 2260666    n
# 2260667    n
# Name: pymnt_plan, Length: 2260668, dtype: str

# %% [markdown]
# CREATING TABLES

# %%
conn.execute("""
    DROP TABLE IF EXISTS borrowers
    """)

conn.execute("""
    CREATE TABLE IF NOT EXISTS borrowers (
        borrower_id INTEGER PRIMARY KEY AUTOINCREMENT,
        emp_title CHAR,
        emp_length INTEGER,
        annual_inc FLOAT, 
        avg_cur_bal FLOAT, 
        tot_cur_bal FLOAT, 
        home_ownership CHAR, 
        addr_state CHAR
    )
""")
conn.commit()

# %%
pd.read_sql("SELECT * FROM borrowers", conn)
# Out:
# Empty DataFrame
# Columns: [borrower_id, emp_title, emp_length, annual_inc, avg_cur_bal, tot_cur_bal, home_ownership, addr_state]
# Index: []

# %%
conn.execute("PRAGMA foreign_keys = ON")

# %%
conn.execute("""
    DROP TABLE IF EXISTS loans
    """)

conn.execute("""             
    CREATE TABLE IF NOT EXISTS loans (
        loan_id INTEGER PRIMARY KEY AUTOINCREMENT,
        loan_status TEXT,
        issue_d DATE,
        borrower_id INT,
        int_rate FLOAT, 
        installment FLOAT, 
        loan_amnt FLOAT, 
        funded_amnt FLOAT, 
        term INT, 
        pymnt_plan CHAR, 
        application_type CHAR,
        purpose TEXT,
        sub_grade CHAR, 
        grade CHAR,
        FOREIGN KEY (borrower_id) REFERENCES borrowers(borrower_id)
    )

""")
conn.commit()

# %%
pd.read_sql("SELECT * FROM loans", conn)
# Out:
# Empty DataFrame
# Columns: [loan_id, loan_status, issue_d, borrower_id, int_rate, installment, loan_amnt, funded_amnt, term, pymnt_plan, application_type, purpose, sub_grade, grade]
# Index: []

# %%
conn.execute("""
    DROP TABLE IF EXISTS payments
    """)
conn.execute("""
    CREATE TABLE IF NOT EXISTS payments (
        payment_id INTEGER PRIMARY KEY AUTOINCREMENT,
        tot_coll_amt FLOAT,
        last_pymnt_d DATE,
        loan_id INT,
        last_pymnt_amnt FLOAT, 
        total_pymnt FLOAT,
        FOREIGN KEY (loan_id) REFERENCES loans(loan_id)
    )
""")
conn.commit()

# %%
conn.execute("""
    CREATE TABLE IF NOT EXISTS risk_flags (
        flag_id INTEGER PRIMARY KEY AUTOINCREMENT,
        risk_score FLOAT,
        loan_id INT,
        is_anomaly INTEGER,
        flag_reason TEXT,
        flag_date TEXT,
        FOREIGN KEY (loan_id) REFERENCES loans(loan_id)
    )
""")
conn.commit()

# %%
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
# Out:
#               name
# 0  sqlite_sequence
# 1       risk_flags
# 2        borrowers
# 3            loans
# 4         payments

# %%
pd.read_sql("PRAGMA table_info(borrowers)", conn)
pd.read_sql("PRAGMA table_info(loans)", conn)
pd.read_sql("PRAGMA table_info(payments)", conn)
pd.read_sql("PRAGMA table_info(risk_flags)", conn)
# Out:
#    cid         name     type  notnull dflt_value  pk
# 0    0      flag_id  INTEGER        0       None   1
# 1    1   risk_score    FLOAT        0       None   0
# 2    2      loan_id      INT        0       None   0
# 3    3   is_anomaly  INTEGER        0       None   0
# 4    4  flag_reason     TEXT        0       None   0
# 5    5    flag_date     TEXT        0       None   0

# %%
borrower_cols = ['emp_title', 'emp_length', 'annual_inc', 'avg_cur_bal', 'tot_cur_bal', 'home_ownership', 'addr_state']
df[borrower_cols].to_sql('borrowers', conn, if_exists='append', index=False)
# Out:
# 2260668

# %%
pd.read_sql("SELECT * FROM borrowers",conn)
# Out:
#          borrower_id       emp_title emp_length  annual_inc  avg_cur_bal  \
# 0                  1            Chef  10+ years     55000.0       1878.0
# 1                  2     Postmaster   10+ years     90000.0      24763.0
# 2                  3  Administrative    6 years     59280.0      18383.0
# 3                  4   IT Supervisor  10+ years     92000.0      30505.0
# 4                  5        Mechanic  10+ years     57250.0       9667.0
# ...              ...             ...        ...         ...          ...
# 2260663      2260664    house keeper  10+ years     58000.0       4110.0
# 2260664      2260665   Skilled Labor   < 1 year     30000.0      34640.0
# 2260665      2260666         Teacher  10+ years     64000.0      31623.0
# 2260666      2260667             NaN        NaN     60000.0       8155.0
# 2260667      2260668      BABYSITTER    3 years     60000.0       1982.0
#
#          tot_cur_bal home_ownership addr_state
# 0            16901.0           RENT         NY
# 1           321915.0       MORTGAGE         LA
# 2           110299.0       MORTGAGE         MI
# 3           305049.0       MORTGAGE         WA
# 4           116007.0       MORTGAGE         MD
# ...              ...            ...        ...
# 2260663      45212.0       MORTGAGE         VT
# 2260664     346404.0       MORTGAGE         OR
# 2260665     189735.0            OWN         IL
# 2260666      65238.0           RENT         AK
# 2260667      25760.0           RENT         NY
#
# [2260668 rows x 8 columns]

# %%
loans_cols = ['loan_status','issue_d','int_rate', 'installment','loan_amnt','funded_amnt','term','pymnt_plan','application_type','purpose','sub_grade','grade']
df[loans_cols].to_sql('loans',conn,if_exists='append', index=False)
pd.read_sql("SELECT * FROM loans", conn)
# Out:
#          loan_id loan_status     issue_d borrower_id  int_rate  installment  \
# 0              1     Current  2018-12-01        None     13.56        84.92
# 1              2     Current  2018-12-01        None     18.94       777.23
# 2              3     Current  2018-12-01        None     17.97       180.69
# 3              4     Current  2018-12-01        None     18.94       146.51
# 4              5     Current  2018-12-01        None     16.14       731.78
# ...          ...         ...         ...         ...       ...          ...
# 2260663  2260664     Current  2017-10-01        None     14.08       279.72
# 2260664  2260665  Fully Paid  2017-10-01        None     25.82       358.01
# 2260665  2260666     Current  2017-10-01        None     11.99       332.10
# 2260666  2260667     Current  2017-10-01        None     21.45       327.69
# 2260667  2260668     Current  2017-10-01        None     21.45       451.94
#
#          loan_amnt  funded_amnt  term pymnt_plan application_type  \
# 0           2500.0       2500.0    36          n       Individual
# 1          30000.0      30000.0    60          n       Individual
# 2           5000.0       5000.0    36          n       Individual
# 3           4000.0       4000.0    36          n       Individual
# 4          30000.0      30000.0    60          n       Individual
# ...            ...          ...   ...        ...              ...
# 2260663    12000.0      12000.0    60          n       Individual
# 2260664    12000.0      12000.0    60          n        Joint App
# 2260665    10000.0      10000.0    36          n       Individual
# 2260666    12000.0      12000.0    60          n       Individual
# 2260667    16550.0      16550.0    60          n       Individual
#
#                     purpose sub_grade grade
# 0        debt_consolidation        C1     C
# 1        debt_consolidation        D2     D
# 2        debt_consolidation        D1     D
# 3        debt_consolidation        D2     D
# 4        debt_consolidation        C4     C
# ...                     ...       ...   ...
# 2260663  debt_consolidation        C3     C
# 2260664  debt_consolidation        E4     E
# 2260665  debt_consolidation        B5     B
# 2260666  debt_consolidation        D5     D
# 2260667         credit_card        D5     D
#
# [2260668 rows x 14 columns]

# %%
payments_cols = ['tot_coll_amt','last_pymnt_d','last_pymnt_amnt','total_pymnt']
df[payments_cols].to_sql('payments', conn, if_exists='append',index=False)
pd.read_sql("SELECT * FROM payments", conn)
# Out:
#          payment_id  tot_coll_amt last_pymnt_d loan_id  last_pymnt_amnt  \
# 0                 1           0.0   2019-02-01    None            84.92
# 1                 2        1208.0   2019-02-01    None           777.23
# 2                 3           0.0   2019-02-01    None           180.69
# 3                 4         686.0   2019-02-01    None           146.51
# 4                 5           0.0   2019-02-01    None           731.78
# ...             ...           ...          ...     ...              ...
# 2260663     2260664        7921.0   2019-02-01    None           279.72
# 2260664     2260665         550.0   2018-08-01    None           182.74
# 2260665     2260666          77.0   2019-02-01    None           332.10
# 2260666     2260667         535.0   2019-02-01    None           327.69
# 2260667     2260668           0.0   2019-02-01    None           500.00
#
#           total_pymnt
# 0          167.020000
# 1         1507.110000
# 2          353.890000
# 3          286.710000
# 4         1423.210000
# ...               ...
# 2260663   5360.960000
# 2260664  14499.802172
# 2260665   5306.940000
# 2260666   5207.290000
# 2260667   7355.500000
#
# [2260668 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['mths_since_recent_inq', 'emp_title', 'num_tl_120dpd_2m', 'emp_length',
#        'mo_sin_old_il_acct', 'bc_util', 'percent_bc_gt_75', 'bc_open_to_buy',
#        'mths_since_recent_bc', 'pct_tl_nvr_dlq', 'avg_cur_bal',
#        'mo_sin_old_rev_tl_op', 'num_rev_accts', 'mo_sin_rcnt_rev_tl_op',
#        'num_tl_30dpd', 'tot_cur_bal', 'mo_sin_rcnt_tl',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_op_rev_tl',
#        'num_rev_tl_bal_gt_0', 'num_il_tl', 'total_rev_hi_lim', 'tot_coll_amt',
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'num_bc_tl',
#        'num_actv_rev_tl', 'tot_hi_cred_lim', 'total_il_high_credit_limit',
#        'num_sats', 'num_bc_sats', 'total_bal_ex_mort', 'total_bc_limit',
#        'acc_open_past_24mths', 'mort_acc', 'last_pymnt_d', 'revol_util', 'dti',
#        'pub_rec_bankruptcies', 'collections_12_mths_ex_med',
#        'chargeoff_within_12_mths', 'tax_liens', 'last_credit_pull_d',
#        'inq_last_6mths', 'earliest_cr_line', 'open_acc', 'delinq_amnt',
#        'total_acc', 'acc_now_delinq', 'delinq_2yrs', 'pub_rec', 'annual_inc',
#        'loan_amnt', 'pymnt_plan', 'loan_status', 'issue_d',
#        'verification_status', 'home_ownership', 'installment', 'grade',
#        'sub_grade', 'term', 'funded_amnt_inv', 'funded_amnt', 'int_rate',
#        'collection_recovery_fee', 'recoveries', 'total_rec_late_fee',
#        'last_pymnt_amnt', 'policy_code', 'application_type', 'purpose',
#        'addr_state', 'revol_bal', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_rec_int', 'total_rec_prncp', 'total_pymnt_inv',
#        'total_pymnt', 'hardship_flag', 'disbursement_method',
#        'debt_settlement_flag', 'is_default'],
#       dtype='str')

# %%
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
# Out:
#               name
# 0  sqlite_sequence
# 1       risk_flags
# 2        borrowers
# 3            loans
# 4         payments

# %%
payments_df = df[['tot_coll_amt','last_pymnt_d','last_pymnt_amnt','total_pymnt']]
payments_df['loan_id'] = range(1,len(payments_df)+1)

payments_df.to_sql('payments', conn, if_exists='replace', index=False)
conn.commit()

# %%
loans_df = df[['loan_status', 'issue_d', 'int_rate', 'installment', 
               'loan_amnt', 'funded_amnt', 'term', 'pymnt_plan',
               'application_type', 'purpose', 'sub_grade', 'grade']].copy()

loans_df['borrower_id'] = range(1, len(loans_df) + 1)
loans_df['loan_id'] = range(1, len(loans_df) + 1)

loans_df.to_sql('loans', conn, if_exists='replace', index=False)
conn.commit()

# %%
print(pd.read_sql("SELECT borrower_id, loan_amnt, grade FROM loans LIMIT 5", conn))
print(pd.read_sql("SELECT loan_id, total_pymnt FROM payments LIMIT 5", conn))
print(pd.read_sql("SELECT loan_id FROM loans LIMIT 5", conn))
# Out:
#    borrower_id  loan_amnt grade
# 0            1       2500     C
# 1            2      30000     D
# 2            3       5000     D
# 3            4       4000     D
# 4            5      30000     C
#    loan_id  total_pymnt
# 0        1       167.02
# 1        2      1507.11
# 2        3       353.89
# 3        4       286.71
# 4        5      1423.21
#    loan_id
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
pd.read_sql("SELECT B.annual_inc, L.loan_amnt, L.grade FROM borrowers B INNER JOIN loans L ON L.borrower_id=B.borrower_id INNER JOIN payments P ON P.loan_id = L.loan_id LIMIT 10", conn)
# Out:
#    annual_inc  loan_amnt grade
# 0     55000.0       2500     C
# 1     90000.0      30000     D
# 2     59280.0       5000     D
# 3     92000.0       4000     D
# 4     57250.0      30000     C
# 5    152500.0       5550     C
# 6     51000.0       2000     D
# 7     65000.0       6000     C
# 8     53580.0       5000     D
# 9    300000.0       6000     C

# %%
df.columns
# Out:
# Index(['mths_since_recent_inq', 'emp_title', 'num_tl_120dpd_2m', 'emp_length',
#        'mo_sin_old_il_acct', 'bc_util', 'percent_bc_gt_75', 'bc_open_to_buy',
#        'mths_since_recent_bc', 'pct_tl_nvr_dlq', 'avg_cur_bal',
#        'mo_sin_old_rev_tl_op', 'num_rev_accts', 'mo_sin_rcnt_rev_tl_op',
#        'num_tl_30dpd', 'tot_cur_bal', 'mo_sin_rcnt_tl',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_op_rev_tl',
#        'num_rev_tl_bal_gt_0', 'num_il_tl', 'total_rev_hi_lim', 'tot_coll_amt',
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'num_bc_tl',
#        'num_actv_rev_tl', 'tot_hi_cred_lim', 'total_il_high_credit_limit',
#        'num_sats', 'num_bc_sats', 'total_bal_ex_mort', 'total_bc_limit',
#        'acc_open_past_24mths', 'mort_acc', 'last_pymnt_d', 'revol_util', 'dti',
#        'pub_rec_bankruptcies', 'collections_12_mths_ex_med',
#        'chargeoff_within_12_mths', 'tax_liens', 'last_credit_pull_d',
#        'inq_last_6mths', 'earliest_cr_line', 'open_acc', 'delinq_amnt',
#        'total_acc', 'acc_now_delinq', 'delinq_2yrs', 'pub_rec', 'annual_inc',
#        'loan_amnt', 'pymnt_plan', 'loan_status', 'issue_d',
#        'verification_status', 'home_ownership', 'installment', 'grade',
#        'sub_grade', 'term', 'funded_amnt_inv', 'funded_amnt', 'int_rate',
#        'collection_recovery_fee', 'recoveries', 'total_rec_late_fee',
#        'last_pymnt_amnt', 'policy_code', 'application_type', 'purpose',
#        'addr_state', 'revol_bal', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_rec_int', 'total_rec_prncp', 'total_pymnt_inv',
#        'total_pymnt', 'hardship_flag', 'disbursement_method',
#        'debt_settlement_flag', 'is_default'],
#       dtype='str')

# %%
plt.plot(df.groupby('emp_length')['is_default'].mean()*100)
plt.show()

# %%
plt.bar(df.groupby('term')['is_default'].mean(), height=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.bar(df.groupby('term')['is_default'].mean(), height=1)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.bar(df.groupby('home_ownership')['is_default'].mean()*100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 plt.bar(df.groupby('home_ownership')['is_default'].mean()*100)
#       2 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'
