# %%
import sys
sys.path.append('..')
from src.data_queries import load_clean_data, get_default_rate_by_grade, get_default_rate_by_purpose, get_high_risk_loans

# %%
clean_data = load_clean_data("../data/clean_loan_data.csv")
print(clean_data.shape)
print(get_default_rate_by_grade(clean_data))
print(get_default_rate_by_purpose(clean_data))
print(get_high_risk_loans(clean_data))
# Out:
# (2260668, 86)
# grade
# A     3.242985
# B     7.835348
# C    13.036783
# D    18.640729
# E    26.438561
# F    34.622010
# G    37.762985
# Name: is_default, dtype: float64
# purpose
# car                    8.811894
# credit_card            9.559530
# debt_consolidation    12.796928
# educational           20.754717
# home_improvement      10.240800
# house                 11.028580
# major_purchase        10.742393
# medical               12.252619
# moving                14.218009
# other                 11.668101
# renewable_energy      15.155709
# small_business        18.607477
# vacation              11.027375
# wedding               12.399151
# Name: is_default, dtype: float64
#          mths_since_recent_inq                         emp_title  \
# 10                         4.0                               NaN
# 18                         4.0       Neonatal Nurse Practitioner
# 22                        15.0               driver coordinator
# ...

# %%
print(get_high_risk_loans(clean_data))
# Out:
#          mths_since_recent_inq                         emp_title  \
# 10                         4.0                               NaN
# 18                         4.0       Neonatal Nurse Practitioner
# 22                        15.0               driver coordinator
# 23                         1.0                     gas attendant
# 24                         3.0  Financial Relationship Associate
# ...                        ...                               ...
# 2260661                    0.0                               NaN
# 2260662                    4.0                             Sales
# 2260664                    0.0                     Skilled Labor
# 2260666                    5.0                               NaN
# 2260667                    0.0                        BABYSITTER
#
#          num_tl_120dpd_2m emp_length  mo_sin_old_il_acct  bc_util  \
# 10                    0.0   < 1 year               139.0     94.4
# ...
